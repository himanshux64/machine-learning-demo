# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open('pipe.pkl','rb'))

# %%
# Assume Input user
test_input=np.array([1,'male',21.0,0,0,11.5,'C'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[1, 'male', 21.0, 0, 0, 11.5, 'C']], dtype=object)

# %%
pipe.predict(test_input)
# Out:
# C:\Users\91886\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\91886\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([1])
