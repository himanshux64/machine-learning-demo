# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('dataset/book_issue.csv')
df
# Out:
#     Book_price Size issue
# 0        20000    M   Eng
# 1        87000    S   NaN
# 2        13288  NaN   phd
# 3         6000    M   NaN
# 4         6887    S   Eng
# 5        45675  NaN   NaN
# 6         9765    S   phd
# 7         4256  NaN   phd
# 8         4679    M   Eng
# 9        23456    S   phd
# 10        6429  NaN   NaN
# 11        5689  NaN   NaN
# 12        6196    S   NaN
# 13       25479  NaN   Eng
# 14        7532  NaN   Eng
# 15       97875  NaN   NaN
# 16        7854  NaN   NaN
# 17        9675    M   phd
# 18         566    S   NaN
# 19        2444    M   phd

# %% [markdown]
# # fillna method

# %%
df.isnull().mean()*100
# Out:
# Book_price     0.0
# Size          45.0
# issue         45.0
# dtype: float64

# %%
df['Size'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Size'>

# %%
df['Size'].mode()
# Out:
# 0    S
# Name: Size, dtype: object

# %%
df['issue'].mode()
# Out:
# 0    phd
# Name: issue, dtype: object

# %%
df['Size'].fillna('S',inplace=True)
# Out:
# C:\Users\91886\AppData\Local\Temp\ipykernel_12064\3882365781.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size'].fillna('S',inplace=True)

# %%
df["Size"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Size'>

# %%
df['issue'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='issue'>

# %%
df['issue'].mode()
# Out:
# 0    phd
# Name: issue, dtype: object

# %%
df['issue'].fillna('phd',inplace=True)
# Out:
# C:\Users\91886\AppData\Local\Temp\ipykernel_12064\1431532867.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['issue'].fillna('phd',inplace=True)

# %%
df['issue'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='issue'>

# %% [markdown]
# # using sklearn Simpleimputer

# %%
df.head()
# Out:
#    Book_price Size issue
# 0       20000    M   Eng
# 1       87000    S   phd
# 2       13288    S   phd
# 3        6000    M   phd
# 4        6887    S   Eng

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,1:],df.iloc[:,0],test_size=0.2,random_state=42)

# %%
imp=SimpleImputer(strategy='most_frequent')

# %%
X_train=imp.fit_transform(X_train)
X_test=imp.transform(X_test)

# %%
imp.statistics_
# Out:
# array(['S', 'phd'], dtype=object)

# %%
X_test
# Out:
# array([['M', 'Eng'],
#        ['M', 'phd'],
#        ['S', 'phd'],
#        ['S', 'phd']], dtype=object)
